# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# Base URL for pagination
base_url = "https://www.supermarches.ca/pages/Default.asp"

# Parameters for pagination
params = {
    "page": 1,        # Start from page 1
}

# Headers to simulate a browser request
headers = {"User-Agent": "Mozilla/5.0"}

# List to store extracted food items
food_data = []

# %%
while params["page"] <= 250:
    # Fetch the webpage
    response = requests.get(base_url, params=params, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all <tr> rows
    rows = soup.find_all("tr")
    items_found = False  # Track if items were found on the page

    for row in rows:
        cols = row.find_all("td")
        if len(cols) == 7:  # Ensure valid item structure
            a_tag = cols[1].find("a", class_="dslink")
            
            if a_tag:
                raw_text = a_tag.get_text(separator="\n").strip()
                lines = [line.strip() for line in raw_text.splitlines() if line.strip()]
                
                item_name = lines[0]  # First line is the item name
                extra_info = lines[1] if len(lines) > 1 else ""  # Second line if available
            else:
                raw_text = cols[1].get_text(separator="\n").strip()
                lines = [line.strip() for line in raw_text.splitlines() if line.strip()]
                
                item_name = lines[0]
                extra_info = lines[1] if len(lines) > 1 else ""

            brand = cols[3].get_text(strip=True)

            # Only add extra_info if it's not the same as the brand
            if extra_info and extra_info.lower() != brand.lower():
                item_name = f"{item_name} {extra_info}"

            # Handle multiple prices in the same cell
            price_cell = cols[4].get_text(separator="\n").strip()
            prices = [p.strip() for p in price_cell.splitlines() if p.strip()]  # Split by <br> tags

            store_info = cols[6].get_text(strip=True)

            # Prioritize "/ lb" prices if both "/ lb" and "/ kg" are present
            selected_price = None
            for price in prices:
                if "/ lb" in price:
                    selected_price = price
                    break  # Prioritize the first "/ lb" price
            if not selected_price:  # If no "/ lb" price, use the first valid price
                selected_price = prices[0] if prices else None

            # Validate the selected price
            if selected_price:
                valid_price = (
                    any(char.isdigit() for char in selected_price) and 
                    any(unit in selected_price for unit in ["/ lb", "/ kg", "/ ch.", "/ unité", "$", "/ caisse", "/ sac"])
                )

                if valid_price:
                    food_data.append([item_name, brand, selected_price, store_info])
                    items_found = True
                else:
                    print(f"Skipping invalid price format: {selected_price}")  # Debugging output

    print(f"Scraped Page {params['page']}...")

    if not items_found:
        break  # Stop if no items found on this page

    params["page"] += 1
# Out:
# Skipping invalid price format: 3 / 6.00
# Skipping invalid price format: 3 / 6.00
# Skipping invalid price format: 3 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 1...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 2...
# Skipping invalid price format: 2 / 10.00
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 3...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 4...
# Skipping invalid price format: 2 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 5...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 6...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 7...
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: 2 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 8...
# Skipping invalid price format: 3 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 9...
# Skipping invalid price format: 2 / 41.98
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 10...
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 11...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 12...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 13...
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 14...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 15...
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 16...
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 17...
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 18...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 68.98
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 19...
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 20...
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 21...
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 22...
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 23...
# Skipping invalid price format: 2 / 68.98
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 68.98
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 24...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 25...
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 26...
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 27...
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 69.00
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 28...
# Skipping invalid price format: 2 / 72.00
# Skipping invalid price format: 2 / 43.98
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: 2 / 40.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 29...
# Skipping invalid price format: 2 / 68.98
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 30...
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: 2 / 44.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 31...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 32...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 33...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 34...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 35...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 36...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 37...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 6.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 38...
# Skipping invalid price format: 2 / 6.50
# Skipping invalid price format: 2 / 6.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 39...
# Skipping invalid price format: 2 / 5.50
# Skipping invalid price format: 3 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 40...
# Skipping invalid price format: 3 / 9.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 3 / 9.00
# Skipping invalid price format: 3 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 41...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 42...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 8.00
# Skipping invalid price format: 2 / 8.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 6.88
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 43...
# Skipping invalid price format: 2 / 6.88
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 44...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 45...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 46...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 47...
# Skipping invalid price format: 2 / 3.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 48...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 49...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 50...
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 51...
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: 2 / 8.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 52...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 3 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 53...
# Skipping invalid price format: 2 / 2.66
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 7.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 54...
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 55...
# Skipping invalid price format: 2 / 5.50
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 56...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 3.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 57...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 58...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 4 / 5.00
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 59...
# Skipping invalid price format: 3 / 9.99
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: 2 / 7.50
# Skipping invalid price format: 2 / 7.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 60...
# Skipping invalid price format: 2 / 7.50
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 61...
# Skipping invalid price format: 2 / 8.50
# Skipping invalid price format: 2 / 8.50
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 62...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: 2 / 7.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 63...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 64...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 65...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 66...
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: 2 / 14.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 67...
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 68...
# Skipping invalid price format: 2 / 14.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 69...
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: 2 / 10.00
# Skipping invalid price format: 2 / 10.00
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 70...
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 4.50
# Skipping invalid price format: 2 / 4.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 71...
# Skipping invalid price format: 2 / 4.50
# Skipping invalid price format: 2 / 4.50
# Skipping invalid price format: 2 / 4.50
# Skipping invalid price format: 2 / 13.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 72...
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 73...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 74...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 75...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 5.99 / bte
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 76...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 3 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 77...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 78...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 79...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 80...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 81...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 82...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 83...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 84...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 85...
# Skipping invalid price format: 2 / 7.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 86...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 87...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 88...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 89...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 90...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 91...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 92...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 93...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 94...
# Skipping invalid price format: 2 / 8.58
# Skipping invalid price format: 3 / 4.98
# Skipping invalid price format: 3 / 4.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 95...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 96...
# Skipping invalid price format: 2 / 12.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 97...
# Skipping invalid price format: 2 / 12.00
# Skipping invalid price format: 2 / 12.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 98...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 99...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 100...
# Skipping invalid price format: 2 / 8.58
# Skipping invalid price format: 2 / 8.58
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 101...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 102...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 103...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 104...
# Skipping invalid price format: 3 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 105...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 106...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 2.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 107...
# Skipping invalid price format: 4 / 5.00
# Skipping invalid price format: 4 / 5.00
# Skipping invalid price format: 4 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 108...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 109...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 110...
# Skipping invalid price format: 2 / 5.50
# Skipping invalid price format: 2 / 5.50
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 111...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 112...
# Skipping invalid price format: 2 / 2.22
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 113...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 114...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 115...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 116...
# Skipping invalid price format: 8.99 / pqt
# Skipping invalid price format: 8.99 / pqt
# Skipping invalid price format: 8.99 / pqt
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 117...
# Skipping invalid price format: 8.99 / pqt
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 118...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 119...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 120...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 121...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 122...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 123...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 124...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 125...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 126...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 127...
# Skipping invalid price format: 5 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 128...
# Skipping invalid price format: 2 / 2.98
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 129...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 130...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 131...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 132...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 133...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 134...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 135...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 136...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 137...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 138...
# Skipping invalid price format: 4.99 / pqt
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 139...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 140...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 141...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 142...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 143...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 144...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 145...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 146...
# Skipping invalid price format: 3.49 / bte
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 147...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 3 / 5.00
# Skipping invalid price format: 2 / 12.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 148...
# Skipping invalid price format: 2 / 2.98
# Skipping invalid price format: 2 / 2.98
# Skipping invalid price format: 2 / 6.50
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 149...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 150...
# Skipping invalid price format: 2 / 11.00
# Skipping invalid price format: 2 / 11.00
# Skipping invalid price format: 2 / 11.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 151...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 152...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 153...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 154...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 155...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 156...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 157...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 158...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 159...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 160...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 161...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 162...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 163...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 164...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 165...
# Skipping invalid price format: 3 / 12.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 166...
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 167...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 168...
# Skipping invalid price format: 3 / 12.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 169...
# Skipping invalid price format: 3 / 12.75
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 170...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 171...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 172...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 173...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 174...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 175...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 176...
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 177...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 178...
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 179...
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: 2 / 3.00
# Skipping invalid price format: 3 / 4.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 180...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 181...
# Skipping invalid price format: 2 / 9.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 182...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 183...
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 184...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 185...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 186...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 187...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 188...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 189...
# Skipping invalid price format: 2 / 6.00
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 190...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 191...
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 192...
# Skipping invalid price format: 7.99 / pqt
# Skipping invalid price format: 2 / 4.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 193...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 194...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 195...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 196...
# Skipping invalid price format: 3 / 11.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 197...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 198...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 199...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 200...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 201...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 202...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 203...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 204...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 205...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 206...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 207...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 208...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 209...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 210...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 211...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 212...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 213...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 214...
# Skipping invalid price format: 2 / 7.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 215...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 216...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 217...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 218...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 219...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 220...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 221...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 222...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 223...
# Skipping invalid price format: 3 / 10.00
# Skipping invalid price format: 2 / 5.00
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 224...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 225...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 226...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 227...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 228...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 229...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 230...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 231...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 232...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 233...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 234...
# Skipping invalid price format: Toutes les circulaires
# Scraped Page 235...

# %%
df = pd.DataFrame(food_data, columns=["name", "brand", "price", "Store"])

# %%
df
# Out:
#                                                    name        brand  \
# 0                               Tartare de bœuf surgelé      La Cage
# 1                                Gaufres surgelées Eggo    Kellogg's
# 2     Coquille aux fruits de mer-repas surgelée Voir...          ---
# 3                                 Mets chinois surgelés    Wong Wing
# 4                                    Dumplings surgelés    Wong Wing
# ...                                                 ...          ...
# 1996                          Souvlakis de poulet frais  Marc Angelo
# 1997                                   Dinde effilochée   Maple Leaf
# 1998               Alouettes de poulet farcies Metrogo!          ---
# 1999              Poulet effiloché Apprêtez et savourez   Maple Leaf
# 2000                      Médaillons de poulet surgelés     Flamingo
#
#             price                 Store
# 0     11.99 / ch.       METROCirc.-Mag.
# 1      5.99 / ch.       METROCirc.-Mag.
# 2      6.99 / ch.       METROCirc.-Mag.
# 3      6.99 / ch.     SUPER CCirc.-Mag.
# 4      6.99 / ch.     SUPER CCirc.-Mag.
# ...           ...                   ...
# 1996  12.99 / ch.         IGACirc.-Mag.
# 1997   7.99 / ch.  PHARMAPRIXCirc.-Mag.
# 1998    9.99 / lb       METROCirc.-Mag.
# 1999   7.99 / ch.  PHARMAPRIXCirc.-Mag.
# 2000   9.99 / ch.       METROCirc.-Mag.
#
# [2001 rows x 4 columns]

# %%
# Remove 'Circ.-Mag.' from 'Store Info' and rename to 'Store'
df["store"] = df["Store"].str.replace('Circ.-Mag.', '', regex=True)
df.drop(columns=["Store"], inplace=True)

# Keep original price string in 'Price' column
df["price"] = df["price"].str.replace(',', '.', regex=True)  # Convert commas to decimal points

# Extract numeric price for calculations
df["nominal"] = df["price"].str.extract(r'(\d+\.\d+)')  # Extract only the numeric part

# Filter out invalid data
df["nominal"] = df["nominal"].astype(float)  # Convert nominal price to float
df = df[df["nominal"] < 100]  # Remove any abnormally high prices


# For items appearing with both lb and kg prices, keep only the lb version
df = df.sort_values(by=["name", "brand", "store"])  # Ensures '/ lb' appears before '/ kg'
df = df.drop_duplicates(subset=["name", "brand", "store"], keep="first")  # Keeps '/ lb' if both exist

# Keep only the lowest price per (Item Name, Price, Brand, Store)
df = df.loc[df.groupby(['name', 'price', 'brand', 'store'])['nominal'].idxmin()].reset_index(drop=True)

# %%
df
# Out:
#                                    name             brand        price  \
# 0                 Acétaminophène 325 mg           Tylenol  18.99 / ch.
# 1                 Acétaminophène 500 mg           Tylenol  10.99 / ch.
# 2                 Acétaminophène 500 mg           Tylenol   8.99 / ch.
# 3                Acétaminophène Complet           Tylenol  12.29 / ch.
# 4                Acétaminophène Complet           Tylenol  15.99 / ch.
# ...                                 ...               ...          ...
# 1887               Échalotes françaises  Attitude Fraîche   4.99 / ch.
# 1888                      Écran solaire        Neutrogena  12.99 / ch.
# 1889           Édulcorant sans calories        Sugar Twin   5.99 / ch.
# 1890        Émincé de poitrine de dinde         Selection   7.99 / ch.
# 1891  Émincé de poitrine de dinde cuite            Olymel   9.99 / ch.
#
#            store  nominal
# 0         BRUNET    18.99
# 1     PHARMAPRIX    10.99
# 2         BRUNET     8.99
# 3         BRUNET    12.29
# 4     PHARMAPRIX    15.99
# ...          ...      ...
# 1887     SUPER C     4.99
# 1888     UNIPRIX    12.99
# 1889  FAMILIPRIX     5.99
# 1890     SUPER C     7.99
# 1891        MAXI     9.99
#
# [1892 rows x 5 columns]

# %%
df.to_csv("supermarches.csv", index=False)
