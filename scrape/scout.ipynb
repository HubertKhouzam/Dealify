# %%
import pandas as pd

# %%
df = pd.read_csv('supermarkets.csv')

df.head()
# Out:
#                                name  price store  nominal_price
# 0                  English Cucumber  $2.49  Maxi           2.49
# 1                       Green Onion  $1.79  Maxi           1.79
# 2     Farmer's Market Yellow Onions  $2.99  Maxi           2.99
# 3  Tomato On The Vine Red (1 Bunch)  $5.46  Maxi           5.46
# 4                     Celery Stalks  $3.49  Maxi           3.49

# %%
df[df['name'] == "Tomato On The Vine Red (1 Bunch)"]
# Out:
#                                    name  price    store  nominal_price
# 3      Tomato On The Vine Red (1 Bunch)  $5.46     Maxi           5.46
# 10851  Tomato On The Vine Red (1 Bunch)  $3.12  Super C           3.12
# 23273  Tomato On The Vine Red (1 Bunch)  $5.46  Provigo           5.46

# %%
name_counts = df.groupby('name')['store'].nunique()
duplicated_names = name_counts[name_counts > 1].index

# Filter the DataFrame
filtered_df = df[df['name'].isin(duplicated_names)]

# %%
filtered_df.head(25)
# Out:
#                                                  name  price store  \
# 0                                    English Cucumber  $2.49  Maxi
# 1                                         Green Onion  $1.79  Maxi
# 2                       Farmer's Market Yellow Onions  $2.99  Maxi
# 3                    Tomato On The Vine Red (1 Bunch)  $5.46  Maxi
# 4                                       Celery Stalks  $3.49  Maxi
# 5                                            Broccoli  $2.99  Maxi
# 6                                     Lettuce Iceberg  $2.99  Maxi
# 8                                         Red Peppers  $2.64  Maxi
# 9                                         Cauliflower  $4.99  Maxi
# 10                              Romaine Heart, 3 Pack  $4.99  Maxi
# 11                                      Roma Tomatoes  $0.53  Maxi
# 12                            Farmer's Market Carrots  $3.99  Maxi
# 13                                       Sweet Potato  $2.49  Maxi
# 14                              Tomato Beefsteak  Red  $1.77  Maxi
# 15                                           Zucchini  $1.85  Maxi
# 16                                             Ginger  $1.38  Maxi
# 17                                Sweet Green Peppers  $2.46  Maxi
# 18                                          Red Onion  $2.03  Maxi
# 19  No Name Naturally Imperfect Mixed Sweet Pepper...  $6.00  Maxi
# 20                                     Broccoli Crown  $2.99  Maxi
# 21                      Rooster Garlic Bulbs, 3-count  $0.99  Maxi
# 22           President's Choice Whole White Mushrooms  $2.99  Maxi
# 23                                     Pumpkin, Large  $3.99  Maxi
# 24             Farmer's Market Yellow Potato 10lb Bag  $6.99  Maxi
# 25                                    Colossal Garlic  $1.54  Maxi
#
#     nominal_price
# 0            2.49
# 1            1.79
# 2            2.99
# 3            5.46
# 4            3.49
# 5            2.99
# 6            2.99
# 8            2.64
# 9            4.99
# 10           4.99
# 11           0.53
# 12           3.99
# 13           2.49
# 14           1.77
# 15           1.85
# 16           1.38
# 17           2.46
# 18           2.03
# 19           6.00
# 20           2.99
# 21           0.99
# 22           2.99
# 23           3.99
# 24           6.99
# 25           1.54

# %%
df[df['name'] == 'Roma Tomato']
# Out:
# Empty DataFrame
# Columns: [name, price, store, nominal_price]
# Index: []
